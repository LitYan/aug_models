# %%
#20200427
#iron crystal 
#train pix2pix 
# %run ./scripts/train_pix2pix.py   --name iron_label2real_pix2pix_real_10 \
--gpu_ids 0,1 --batch_size 8 --checkpoints_dir './ckpts/aug_models' \
--dataroot './datasets/' --phase 'train' --label_dir 'real_labels' --image_dir 'real_images' \
--record_txt './datasets/train/records_txt/real_10.txt' \
--display_port 6006 --display_env 'real_10'
# Out:
# ----------------- Options ---------------
#                batch_size: 8                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./ckpts/aug_models
#            continue_train: False
#                  dataroot: ./datasets/                   	[default: ./datasets]
#              dataset_mode: pix2pix
#               display_env: real_10                       	[default: main]
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 6006                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  fineSize: 400
#                   gpu_ids: 0,1                           	[default: 0]
#                 image_dir: real_images
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 label_dir: real_labels
#                 lambda_L1: 100.0
#                  loadSize: 400
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: lambda
#          max_dataset_size: inf
#                     model: pix2pix
#                n_layers_D: 3
#                      name: iron_label2real_pix2pix_real_10	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_16
#                       ngf: 64
#                     niter: 100
#               niter_decay: 100
#                no_dropout: False
#                   no_flip: False
#          no_label_inverse: False
#                  no_lsgan: True
#                      norm: batch
#               num_threads: 4
#                 output_nc: 1
#                     phase: train
#                 pool_size: 0
#                print_freq: 100
#                record_txt: ./datasets/train/records_txt/real_10.txt	[default: None]
#            resize_or_crop: resize_and_crop
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [Pix2pixDataset] was created
# #training images = 280
# WARNING:root:Setting up a new session...
# initialize network with normal
# initialize network with normal
# model [Pix2PixModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 12.983 M
# [Network D] Total number of parameters : 2.765 M
# -----------------------------------------------
# create images directory ./ckpts/aug_models/iron_label2real_pix2pix_real_10/images...
# (epoch: 1, iters: 200, time: 0.044, data: 0.456) G_GAN: 2.9832 G_L1: 69.6825 D_real: 0.0504 D_fake: 0.0620
# End of epoch 1 / 200 	 Time Taken: 19 sec
# learning rate = 0.0002000
# (epoch: 2, iters: 120, time: 0.094, data: 0.005) G_GAN: 3.0909 G_L1: 23.9634 D_real: 0.1269 D_fake: 0.0604
# End of epoch 2 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch: 3, iters: 40, time: 0.058, data: 0.004) G_GAN: 1.0738 G_L1: 10.0197 D_real: 0.2179 D_fake: 0.0594
# (epoch: 3, iters: 240, time: 0.088, data: 0.010) G_GAN: 0.9863 G_L1: 8.3182 D_real: 0.1801 D_fake: 0.6367
# End of epoch 3 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch: 4, iters: 160, time: 0.043, data: 0.003) G_GAN: 1.9133 G_L1: 9.3875 D_real: 0.4045 D_fake: 0.0789
# End of epoch 4 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch: 5, iters: 80, time: 0.070, data: 0.003) G_GAN: 1.0616 G_L1: 7.4729 D_real: 0.4071 D_fake: 0.5561
# (epoch: 5, iters: 280, time: 0.047, data: 0.005) G_GAN: 2.3293 G_L1: 8.2306 D_real: 0.1560 D_fake: 0.0886
# saving the model at the end of epoch 5, iters 1400
# End of epoch 5 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch: 6, iters: 200, time: 0.079, data: 0.625) G_GAN: 1.5155 G_L1: 8.4833 D_real: 0.2507 D_fake: 0.2676
# End of epoch 6 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch: 7, iters: 120, time: 0.046, data: 0.003) G_GAN: 2.5823 G_L1: 8.1931 D_real: 2.3260 D_fake: 0.0825
# End of epoch 7 / 200 	 Time Taken: 11 sec
# learning rate = 0.0002000
# (epoch:
/ 200 	 Time Taken: 7 sec
# learning rate = 0.0000059
# (epoch: 198, iters: 40, time: 0.065, data: 0.003) G_GAN: 0.8849 G_L1: 4.5387 D_real: 0.6018 D_fake: 0.5873
# (epoch: 198, iters: 240, time: 0.032, data: 0.002) G_GAN: 0.9805 G_L1: 4.6108 D_real: 0.5513 D_fake: 0.5283
# End of epoch 198 / 200 	 Time Taken: 7 sec
# learning rate = 0.0000040
# (epoch: 199, iters: 160, time: 0.076, data: 0.003) G_GAN: 0.8622 G_L1: 4.3667 D_real: 0.6755 D_fake: 0.5756
# End of epoch 199 / 200 	 Time Taken: 7 sec
# learning rate = 0.0000020
# (epoch: 200, iters: 80, time: 0.032, data: 0.003) G_GAN: 0.8825 G_L1: 4.7356 D_real: 0.5527 D_fake: 0.5773
# (epoch: 200, iters: 280, time: 0.070, data: 0.003) G_GAN: 0.9050 G_L1: 4.5826 D_real: 0.4917 D_fake: 0.5661
# saving the model at the end of epoch 200, iters 56000
# End of epoch 200 / 200 	 Time Taken: 8 sec
# learning rate = 0.0000000

# %%
#pix2pix
#generate synthetic data
# %run ./scripts/generate_samples.py  --name iron_label2real_pix2pix_real_5_o  --num_test 28800 \
--gpu_ids 0 --batch_size 1 --checkpoints_dir '../pytorch-cyclegan-and-pix2pix/checkpoints_iron_label2img/' \
--dataroot './datasets/' --phase 'train' --label_dir 'syn_labels' \
--results_dir './datasets/train'
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ../pytorch-cyclegan-and-pix2pix/checkpoints_iron_label2img/	[default: ./ckpts/aug_models]
#                  dataroot: ./datasets/                   	[default: ./datasets]
#              dataset_mode: pix2pix
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                  fineSize: 400
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 label_dir: syn_labels                    	[default: synthtic_labels]
#                  loadSize: 400
#                 load_iter: 0                             	[default: 0]
#          max_dataset_size: inf
#                     model: pix2pix
#                      name: iron_label2real_pix2pix_real_5_o	[default: experiment_name]
#                      netG: unet_16
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#          no_label_inverse: False
#                      norm: batch
#                  num_test: 28800                         	[default: 50]
#               num_threads: 4
#                 output_nc: 1
#                     phase: train
#                record_txt: None
#            resize_or_crop: resize_and_crop
#               results_dir: ./datasets/train              	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [Pix2pixDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from ../pytorch-cyclegan-and-pix2pix/checkpoints_iron_label2img/iron_label2real_pix2pix_real_5_o/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 12.983 M
# -----------------------------------------------
# processing (0000)-th image... ./datasets/train/syn_labels/0.png
# processing (0005)-th image... ./datasets/train/syn_labels/10000.png
# processing (0010)-th image... ./datasets/train/syn_labels/10005.png
# processing (0015)-th image... ./datasets/train/syn_labels/1001.png
# processing (0020)-th image... ./datasets/train/syn_labels/10014.png
# processing (0025)-th image... ./datasets/train/syn_labels/10019.png
# processing (0030)-th image... ./datasets/train/syn_labels/10023.png
# processing (0035)-th image... ./datasets/train/syn_labels/10028.png
# processing (0040)-th image... ./datasets/train/syn_labels/10032.png
# processing (0045)-th image... ./datasets/train/syn_labels/10037.png
# processing (0050)-th image... ./datasets/train/syn_labels/10041.png
# processing (0055)-th image... ./datasets/train/syn_labels/10046.png
# processing (0060)-th image... ./datasets/train/syn_labels/10050.png
# processing (0065)-th image... ./datasets/train/syn_labels/10055.png
# processing (0070)-th image... ./datasets/train/syn_labels/1006.png
# processing (0075)-th image... ./datasets/train/syn_labels/10064.png
# processing (0080)-th image... ./datasets/train/syn_labels/10069.png
# processing (0085)-th image... ./datasets/train/syn_labels/10073.png
# processing (0090)-th image... ./datasets/train/syn_labels/10078.png
# processing (0095)-th image... ./datasets/train/syn_labels/10082.png
# processing (0100)-th image... ./datasets/train/syn_labels/10087.png
# processing (0105)-th image... ./datasets/train/syn_labels/10091.png
# processing (0110)-th image... ./datasets/train/syn_labels/10096.png
# processing (0115)-th image... ./datasets/train/syn_labels/1010.png
# processing (0120)-th image... ./datasets/train/syn_labels/10104.png
# processing (0125)-th image... ./datasets/train/syn_labels/10109.png
# processing (0130)-th image... ./datasets/train/syn_labels/10113.png
# processing (0135)-th image... ./datasets/train/syn_labels/10118.png
# processing (0140)-th image... ./datasets/train/syn_labels/10122.png
# processing (0145)-th image... ./datasets/train/syn_labels/10127.png
# processing (0150)-th image... ./datasets/train/syn_labels/10131.png
# processing (0155)-th image... ./datasets/train/syn_labels/10136.png
# processing (0160)-th image... ./datasets/train/syn_labels/10140.png
# processing (0165)-th image... ./datasets/train/syn_labels/10145.png
# processing (0170)-th image... ./datasets/train/syn_labels/1015.png
# processing (0175)-th image... ./datasets/train/syn_labels/10154.png
# processing (0180)-th image... ./datasets/train/syn_labels/10159.png
# processing (0185)-th image... ./datasets/train/syn_labels/10163.png
# processing (0190)-th image... ./datasets/train/syn_labels/10168.png
# processing (0195)-th image... ./datasets/train/syn_labels/10172.png
# processing (0200)-th image... ./datasets/train/syn_labels/10177.png
# processing (0205)-th image... ./datasets/train/syn_labels/10181.png
# processing (0210)-th image... ./datasets/train/syn_labels/10186.png
# processing (0215)-th image... ./datasets/train/syn_labels/10190.png
# processing (0220)-th image... ./datasets/train/syn_labels/10195.png
# processing (0225)-th image... ./datasets/train/syn_labels/102.png
# processing (0230)-th image... ./datasets/train/syn_labels/10203.png
# processing (0235)-th image... ./datasets/train/syn_labels/10208.png
# processing (0240)-th image... ./datasets/train/syn_labels/10212.png
# processing (0245)-th image... ./datasets/train/syn_labels/10217.png
# processing (0250)-th image... ./datasets/train/syn_labels/10221.png
# processing (0255)-th image... ./datasets/train/syn_labels/10226.png
# processing (0260)-th image... ./datasets/train/syn_labels/10230.png
# processing (0265)-th image... ./datasets/train/syn_labels/10235.png
# processing (0270)-th image... ./datasets/train/syn_labels/1024.png
# processing (0275)-th image... ./datasets/train/syn_labels/10244.png
# processing (0280)-th image... ./datasets/train/syn_labels/10249.png
# processing (0285)-th image... ./datasets/train/syn_labels/10253.png
# processing (0290)-th image... ./datasets/train/syn_labels/10258.png
# processing (0295)-th image... ./datasets/train/syn_labels/10262.png
# processing (0300)-th image... ./datasets/train/syn_labels/10267.png
# processing (0305)-th image... ./datasets/train/syn_labels/10271.png
# processing (0310)-th image... ./datasets/train/syn_labels/10276.png
# processing (0315)-th image... ./datasets/train/syn_labels/10280.png
# processing (0320)-th image... ./datasets/train/syn_labels/10285.png
# processing (0325)-th image... ./datasets/train/syn_labels/1029.png
# processing (0330)-th image... ./datasets/train/syn_labels/10294.png
# processing (0335)-th image... ./datasets/train/syn_labels/10299.png
# processing (0340)-th image... ./datasets/train/syn_labels/10302.png
# processing (0345)-th image... ./datasets/train/syn_labels/10307.png
# processing (0350)-th image... ./datasets/train/syn_labels/10311.png
# processing (0355)-th image... ./datasets/train/syn_labels/10316.png
# processing (0360)-th image... ./datasets/train/syn_labels/10320.png
# processing (0365)-th image... ./datasets/train/syn_labels/10325.png
# processing (0370)-th image... ./datasets/train/syn_labels/1033.png
# processing (0375)-th image... ./datasets/train/syn_labels/10334.png
# processing (0380)-th image... ./datasets/train/syn_labels/10339.png
# processing (0385)-th image... ./datasets/train/syn_labels/10343.png
# processing (0390)-th image... ./datasets/train/syn_labels/10348.png
# processing (0395)-th image... ./datasets/train/syn_labels/10352.png
# processing (0400)-th image... ./datasets/train/syn_labels/10357.png
# processing (0405)-th image... ./datasets/train/syn_labels/10361.png
# processing (0410)-th image... ./datasets/train/syn_labels/10366.png
# processing (0415)-th image... ./datasets/train/syn_labels/10370.png
# processing (0420)-th image... ./datasets/train/syn_labels/10375.png
# processing (0425)-th image... ./datasets/train/syn_labels/1038.png
# processing (0430)-th image... ./datasets/train/syn_labels/10384.png
# processing (0435)-th image... ./datasets/train/syn_labels/10389.png
# processing (0440)-th image... ./datasets/train/syn_labels/10393.png
# processing (0445)-th image... ./datasets/train/syn_labels/10398.png
# processing (0450)-th image... ./datasets/train/syn_labels/10401.png
# processing (0455)-th image... ./datasets/train/syn_labels/10406.png
# processing (0460)-th image... ./datasets/train/syn_labels/10410.png
# processing (0465)-th image... ./datasets/train/syn_labels/10415.png
# processing (0470)-th image... ./datasets/train/syn_labels/1042.png
# processing (0475)-th image... ./datasets/train/syn_labels/10424.png
# processing (0480)-th image... ./datasets/train/syn_labels/10429.png
# processing (0485)-th image... ./datasets/train/syn_labels/10433.png
# processing (0490)-th image... ./datasets/train/syn_labels/10438.png
# processing (0495)-th image... ./datasets/train/syn_labels/10442.png
# processing (0500)-th image... ./datasets/train/syn_labels/10447.png
# processing (0505)-th image... ./datasets/train/syn_labels/10451.png
# processing (0510)-th image... ./datasets/train/syn_labels/10456.png
# processing (0515)-th image... ./datasets/train/syn_labels/10460.png
# processing (0520)-th image... ./datasets/train/syn_labels/10465.png
# processing (0525)-th image... ./datasets/train/syn_labels/1047.png
# processing (0530)-th image... ./datasets/train/syn_labels/10474.png
# processing (0535)-th image... ./datasets/train/syn_labels/10479.png
# processing (0540)-th image... ./datasets/train/syn_labels/10483.png
# processing (0545)-th image... ./datasets/train/syn_labels/10488.png
# processing (0550)-th image... ./datasets/train/syn_labels/10492.png
# processing (0555)-th image... ./datasets/train/syn_labels/10497.png
# processing (0560)-th image... ./datasets/train/syn_labels/10500.png
# processing (0565)-th image... ./datasets/train/syn_labels/10505.png
# processing (0570)-th image... ./datasets/train/syn_labels/1051.png
# processing (0575)-th image... ./datasets/train/syn_labels/10514.png
# processing (0580)-th image... ./datasets/train/syn_labels/10519.png
# processing (0585)-th image... ./datasets/train/syn_labels/10523.png
# processing (0590)-th image... ./datasets/train/syn_labels/10528.png
# processing (0595)-th image... ./datasets/train/syn_labels/10532.png
# processing (0600)-th image... ./datasets/train/syn_labels/10537.png
# processing (0605)-th image... ./datasets/train/syn_labels/10541.png
# processing (0610)-th image... ./datasets/train/syn_labels/10546.png
# processing (0615)-th image... ./datasets/train/syn_labels/10550.png
# processing (0620)-th image... ./datasets/train/syn_labels/10555.png
# processing (0625)-th image... ./datasets/train/syn_labels/1056.png
# processing (0630)-th image... ./datasets/train/syn_labels/10564.png
# processing (0635)-th image... ./datasets/train/syn_labels/10569.png
# processing (0640)-th image... ./datasets/train/syn_labels/10573.png
# processing (0645)-th image... ./datasets/train/syn_labels/10578.png
# processing (0650)-th image... ./datasets/train/syn_labels/10582.png
# processing (0655)-th image... ./datasets/train/syn_labels/10587.png
# processing (0660)-th image... ./datasets/train/syn_labels/10591.png
# processing (0665)-th image... ./datasets/train/syn_labels/10596.png
# processing (0670)-th image... ./datasets/train/syn_labels/1060.png
# processing (0675)-th image... ./datasets/train/syn_labels/10604.png
# processing (0680)-th image... ./datasets/train/syn_labels/10609.png
# processing (0685)-th image... ./datasets/train/syn_labels/10613.png
# processing (0690)-th image... ./datasets/train/syn_labels/10618.png
# processing (0695)-th image... ./datasets/train/syn_labels/10622.png
# processing (0700)-th image... ./datasets/train/syn_labels/10627.png
# processing (0705)-th image... ./datasets/train/syn_labels/10631.png
# processing (0710)-th image... ./datasets/train/syn_labels/10636.png
# processing (0715)-th image... ./datasets/train/syn_labels/10640.png
# processing (0720)-th image... ./datasets/train/syn_labels/10645.png
# processing (0725)-th image... ./datasets/train/syn_labels/1065.png
# processing (0730)-th image... ./datasets/train/syn_labels/10654.png
# processing (0735)-th image... ./datasets/train/syn_labels/10659.png
# processing (0740)-th image... ./datasets/train/syn_labels/10663.png
# processing (0745)-th image... ./datasets/train/syn_labels/10668.png
# processing (0750)-th image... ./datasets/train/syn_labels/10672.png
# processing (0755)-th image... ./datasets/train/syn_labels/10677.png
# processing (0760)-th image... ./datasets/train/syn_labels/10681.png
# processing (0765)-th image... ./datasets/train/syn_labels/10686.png
# processing (0770)-th image... ./datasets/train/syn_labels/10690.png
# processing (0775)-th image... ./datasets/train/syn_labels/10695.png
# processing (0780)-th image... ./datasets/train/syn_labels/107.png
# processing (0785)-th image... ./datasets/train/syn_labels/10703.png
# processing (0790)-th image... ./datasets/train/syn_labels/10708.png
# processing (0795)-th image... ./datasets/train/syn_labels/10712.png
# processing (0800)-th image... ./datasets/train/syn_labels/10717.png
# processing (0805)-th image... ./datasets/train/syn_labels/10721.png
# processing (0810)-th image... ./datasets/train/syn_labels/10726.png
# processing (0815)-th image... ./datasets/train/syn_labels/10730.png
# processing (0820)-th image... ./datasets/train/syn_labels/10735.png
# processing (0825)-th image... ./datasets/train/syn_labels/1074.png
# processing (0830)-th image... ./datasets/train/syn_labels/10744.png
# processing (0835)-th image... ./datasets/train/syn_labels/10749.png
# processing (0840)-th image... ./datasets/train/syn_labels/10753.png
# processing (0845)-th image... ./datasets/train/syn_labels/10758.png
# processing (0850)-th image... ./datasets/train/syn_labels/10762.png
# processing (0855)-th image... ./datasets/train/syn_labels/10767.png
# processing (0860)-th image... ./datasets/train/syn_labels/10771.png
# processing (0865)-th image... ./datasets/train/syn_labels/10776.png
# processing (0870)-th image... ./datasets/train/syn_labels/10780.png
# processing (0875)-th image... ./datasets/train/syn_labels/10785.png
# processing (0880)-th image... ./datasets/train/syn_labels/1079.png
# processing (0885)-th image... ./datasets/train/syn_labels/10794.png
# processing (0890)-th image... ./datasets/train/syn_labels/10799.png
# processing (0895)-th image... ./datasets/train/syn_labels/10802.png
# processing (0900)-th image... ./datasets/train/syn_labels/10807.png
# processing (0905)-th image... ./datasets/train/syn_labels/10811.png
# processing (0910)-th image... ./datasets/train/syn_labels/10816.png
# processing (0915)-th image... ./datasets/train/syn_labels/10820.png
# processing (0920)-th image... ./datasets/train/syn_labels/10825.png
# processing (0925)-th image... ./datasets/train/syn_labels/1083.png
# processing (0930)-th image... ./datasets/train/syn_labels/10834.png
# processing (0935)-th image... ./datasets/train/syn_labels/10839.png
# processing (0940)-th image... ./datasets/train/syn_labels/10843.png
# processing (0945)-th image... ./datasets/train/syn_labels/10848.png
# processing (0950)-th image... ./datasets/train/syn_labels/10852.png
# processing (0955)-th image... ./datasets/train/syn_labels/10857.png
# processing (0960)-th image... ./datasets/train/syn_labels/10861.png
# processing (0965)-th image... ./datasets/train/syn_labels/10866.png
# processing (0970)-th image... ./datasets/train/syn_labels/10870.png
# processing (0975)-th image... ./datasets/train/syn_labels/10875.png
# processing (0980)-th image... ./datasets/train/syn_labels/1088.png
# processing (0985)-th image... ./datasets/train/syn_labels/10884.png
# processing (0990)-th image... ./datasets/train/syn_labels/10889.png
# processing (0995)-th image... ./datasets/train/syn_labels/10893.png
# processing (1000)-th image... ./datasets/train/syn_labels/10898.png
# processing (1005)-th image... ./datasets/train/syn_labels/10901.png
# processing (1010)-th image... ./datasets/train/syn_labels/10906.png
# processing (1015)-th image... ./datasets/train/syn_labels/10910.png
# processing (1020)-th image... ./datasets/train/syn_labels/10915.png
# processing (1025)-th image... ./datasets/train/syn_labels/1092.png
# processing (1030)-th image... ./datasets/train/syn_labels/10924.png
# processing (1035)-th image... ./datasets/train/syn_labels/10929.png
# processing (1040)-th image... ./datasets/train/syn_labels/10933.png
# processing (1045)-th image... ./datasets/train/syn_labels/10938.png
# processing (1050)-th image... ./datasets/train/syn_labels/10942.png
# processing (1055)-th image... ./datasets/train/syn_labels/10947.png
# processing (1060)-th image... ./datasets/train/syn_labels/10951.png
# processing (1065)-th image... ./datasets/train/syn_labels/10956.png
# processing (1070)-th image... ./datasets/train/syn_labels/10960.png
# processing (1075)-th image... ./datasets/train/syn_labels/10965.png
# processing (1080)-th image... ./datasets/train/syn_labels/1097.png
# processing (1085)-th image... ./datasets/train/syn_labels/10974.png
# processing (1090)-th image... ./datasets/train/syn_labels/10979.png
# processing (1095)-th image... ./datasets/train/syn_labels/10983.png
# processing (1100)-th image... ./datasets/train/syn_labels/10988.png
# processing (1105)-th image... ./datasets/train/syn_labels/10992.png
# processing (1110)-th image... ./datasets/train/syn_labels/10997.png
# processing (1115)-th image... ./datasets/train/syn_labels/1100.png
# processing (1120)-th image... ./datasets/train/syn_labels/11004.png
# processing (1125)-th image... ./datasets/train/syn_labels/11009.png
# processing (1130)-th image... ./datasets/train/syn_labels/11013.png
# processing (1135)-th image... ./datasets/train/syn_labels/11018.png
# processing (1140)-th image... ./datasets/train/syn_labels/11022.png
# processing (1145)-th image... ./datasets/train/syn_labels/11027.png
# processing (1150)-th image... ./datasets/train/syn_labels/11031.png
# processing (1155)-th image... ./datasets/train/syn_labels/11036.png
# processing (1160)-th image... ./datasets/train/syn_labels/11040.png
# processing (1165)-th image... ./datasets/train/syn_labels/11045.png
# processing (1170)-th image... ./datasets/train/syn_labels/1105.png
# processing (1175)-th image... ./datasets/train/syn_labels/11054.png
# processing (1180)-th image... ./datasets/train/syn_labels/11059.png
# processing (1185)-th image... ./datasets/train/syn_labels/11063.png
# processing (1190)-th image... ./datasets/train/syn_labels/11068.png
# processing (1195)-th image... ./datasets/train/syn_labels/11072.png
# processing (1200)-th image... ./datasets/train/syn_labels/11077.png
# processing (1205)-th image... ./datasets/train/syn_labels/11081.png
# processing (1210)-th image... ./datasets/train/syn_labels/11086.png
# processing (1215)-th image... ./datasets/train/syn_labels/11090.png
# processing (1220)-th image... ./datasets/train/syn_labels/11095.png
# processing (1225)-th image... ./datasets/train/syn_labels/111.png
# processing (1230)-th image... ./datasets/train/syn_labels/11103.png
# processing (1235)-th image... ./datasets/train/syn_labels/11108.png
# processing (1240)-th image... ./datasets/train/syn_labels/11112.png
# processing (1245)-th image... ./datasets/train/syn_labels/11117.png
# processing (1250)-th image... ./datasets/train/syn_labels/11121.png
# processing (1255)-th image... ./datasets/train/syn_labels/11126.png
# processing (1260)-th image... ./datasets/train/syn_labels/11130.png
# processing (1265)-th image... ./datasets/train/syn_labels/11135.png
# processing (1270)-th image... ./datasets/train/syn_labels/1114.png
# processing (1275)-th image... ./datasets/train/syn_labels/11144.png
# processing (1280)-th image... ./datasets/train/syn_labels/11149.png
# processing (1285)-th image... ./datasets/train/syn_labels/11153.png
# processing (1290)-th image... ./datasets/train/syn_labels/11158.png
# processing (1295)-th image... ./datasets/train/syn_labels/11162.png
# processing (1300)-th image... ./datasets/train/syn_labels/11167.png
# processing (1305)-th image... ./datasets/train/syn_labels/11171.png
# processing (1310)-th image... ./datasets/train/syn_labels/11176.png
# processing (1315)-th image... ./datasets/train/syn_labels/11180.png
# processing (1320)-th image... ./datasets/train/syn_labels/11185.png
# processing (1325)-th image... ./datasets/train/syn_labels/1119.png
# processing (1330)-th image... ./datasets/train/syn_labels/11194.png
# processing (1335)-th image... ./datasets/train/syn_labels/11199.png
# processing (1340)-th image... ./datasets/train/syn_labels/11202.png
# processing (1345)-th image... ./datasets/train/syn_labels/11207.png
# processing (1350)-th image... ./datasets/train/syn_labels/11211.png
# processing (1355)-th image... ./datasets/train/syn_labels/11216.png
# processing (1360)-th image... ./datasets/train/syn_labels/11220.png
# processing (1365)-th image... ./datasets/train/syn_labels/11225.png
# processing (1370)-th image... ./datasets/train/syn_labels/1123.png
# processing (1375)-th image... ./datasets/train/syn_labels/11234.png
# processing (1380)-th image... ./datasets/train/syn_labels/11239.png
# processing (1385)-th image... ./datasets/train/syn_labels/11243.png
# processing (1390)-th image... ./datasets/train/syn_labels/11248.png
# processing (1395)-th image... ./datasets/train/syn_labels/11252.png
# processing (1400)-th image... ./datasets/train/syn_labels/11257.png
# processing (1405)-th image... ./datasets/train/syn_labels/11261.png
# processing (1410)-th image... ./datasets/train/syn_labels/11266.png
# processing (1415)-th image... ./datasets/train/syn_labels/11270.png
# processing (1420)-th image... ./datasets/train/syn_labels/11275.png
# processing (1425)-th image... ./datasets/train/syn_labels/1128.png
# processing (1430)-th image... ./datasets/train/syn_labels/11284.png
# processing (1435)-th image... ./datasets/train/syn_labels/11289.png
# processing (1440)-th image... ./datasets/train/syn_labels/11293.png
# processing (1445)-th image... ./datasets/train/syn_labels/11298.png
# processing (1450)-th image... ./datasets/train/syn_labels/11301.png
# processing (1455)-th image... ./datasets/train/syn_labels/11306.png
# processing (1460)-th image... ./datasets/train/syn_labels/11310.png
# processing (1465)-th image... ./datasets/train/syn_labels/11315.png
# processing (1470)-th image... ./datasets/train/syn_labels/1132.png
# processing (1475)-th image... ./datasets/train/syn_labels/11324.png
# processing (1480)-th image... ./datasets/train/syn_labels/11329.png
# processing (1485)-th image... ./datasets/train/syn_labels/11333.png
# processing (1490)-th image... ./datasets/train/syn_labels/11338.png
# processing (1495)-th image... ./datasets/train/syn_labels/11342.png
# processing (1500)-th image... ./datasets/train/syn_labels/11347.png
# processing (1505)-th image... ./datasets/train/syn_labels/11351.png
# processing (1510)-th image... ./datasets/train/syn_labels/11356.png
# processing (1515)-th image... ./datasets/train/syn_labels/11360.png
# processing (1520)-th image... ./datasets/train/syn_labels/11365.png
# processing (1525)-th image... ./datasets/train/syn_labels/1137.png
# processing (1530)-th image... ./datasets/train/syn_labels/11374.png
# processing (1535)-th image... ./datasets/train/syn_labels/11379.png
# processing (1540)-th image... ./datasets/train/syn_labels/11383.png
# processing (1545)-th image... ./datasets/train/syn_labels/11388.png
# processing (1550)-th image... ./datasets/train/syn_labels/11392.png
# processing (1555)-th image... ./datasets/train/syn_labels/11397.png
# processing (1560)-th image... ./datasets/train/syn_labels/11400.png
# processing (1565)-th image... ./datasets/train/syn_labels/11405.png
# processing (1570)-th image... ./datasets/train/syn_labels/1141.png
# processing (1575)-th image... ./datasets/train/syn_labels/11414.png
# processing (1580)-th image... ./datasets/train/syn_labels/11419.png
# processing (1585)-th image... ./datasets/train/syn_labels/11423.png
# processing (1590)-th image... ./datasets/train/syn_labels/11428.png
# processing (1595)-th image... ./datasets/train/syn_labels/11432.png
# processing (1600)-th image... ./datasets/train/syn_labels/11437.png
# processing (1605)-th image... ./datasets/train/syn_labels/11441.png
# processing (1610)-th image... ./datasets/train/syn_labels/11446.png
# processing (1615)-th image... ./datasets/train/syn_labels/11450.png
# processing (1620)-th image... ./datasets/train/syn_labels/11455.png
# processing (1625)-th image... ./datasets/train/syn_labels/1146.png
# processing (1630)-th image... ./datasets/train/syn_labels/11464.png
# processing (1635)-th image... ./datasets/train/syn_labels/11469.png
# processing (1640)-th image... ./datasets/train/syn_labels/11473.png
# processing (1645)-th image... ./datasets/train/syn_labels/11478.png
# processing (1650)-th image... ./datasets/train/syn_labels/11482.png
# processing (1655)-th image... ./datasets/train/syn_labels/11487.png
# processing (1660)-th image... ./datasets/train/syn_labels/11491.png
# processing (1665)-th image... ./datasets/train/syn_labels/11496.png
# processing (1670)-th image... ./datasets/train/syn_labels/1150.png
# processing (1675)-th image... ./datasets/train/syn_labels/11504.png
# processing (1680)-th image... ./datasets/train/syn_labels/11509.png
# processing (1685)-th image... ./datasets/train/syn_labels/11513.png
# processing (1690)-th image... ./datasets/train/syn_labels/11518.png
# processing (1695)-th image... ./datasets/train/syn_labels/11522.png
# processing (1700)-th image... ./datasets/train/syn_labels/11527.png
# processing (1705)-th image... ./datasets/train/syn_labels/11531.png
# processing (1710)-th image... ./datasets/train/syn_labels/11536.png
# processing (1715)-th image... ./datasets/train/syn_labels/11540.png
# processing (1720)-th image... ./datasets/train/syn_labels/11545.png
# processing (1725)-th image... ./datasets/train/syn_labels/1155.png
# processing (1730)-th image... ./datasets/train/syn_labels/11554.png
# processing (1735)-th image... ./datasets/train/syn_labels/11559.png
# processing (1740)-th image... ./datasets/train/syn_labels/11563.png
# processing (1745)-th image... ./datasets/train/syn_labels/11568.png
# processing (1750)-th image... ./datasets/train/syn_labels/11572.png
# processing (1755)-th image... ./datasets/train/syn_labels/11577.png
# processing (1760)-th image... ./datasets/train/syn_labels/11581.png
# processing (1765)-th image... ./datasets/train/syn_labels/11586.png
# processing (1770)-th image... ./datasets/train/syn_labels/11590.png
# processing (1775)-th image... ./datasets/train/syn_labels/11595.png
# processing (1780)-th image... ./datasets/train/syn_labels/116.png
# processing (1785)-th image... ./datasets/train/syn_labels/11603.png
# processing (1790)-th image... ./datasets/train/syn_labels/11608.png
# processing (1795)-th image... ./datasets/train/syn_labels/11612.png
# processing (1800)-th image... ./datasets/train/syn_labels/11617.png
# processing (1805)-th image... ./datasets/train/syn_labels/11621.png
# processing (1810)-th image... ./datasets/train/syn_labels/11626.png
# processing (1815)-th image... ./datasets/train/syn_labels/11630.png
# processing (1820)-th image... ./datasets/train/syn_labels/11635.png
# processing (1825)-th image... ./datasets/train/syn_labels/1164.png
# processing (1830)-th image... ./datasets/train/syn_labels/11644.png
# processing (1835)-th image... ./datasets/train/syn_labels/11649.png
# processing (1840)-th image... ./datasets/train/syn_labels/11653.png
# processing (1845)-th image... ./datasets/train/syn_labels/11658.png
# processing (1850)-th image... ./datasets/train/syn_labels/11662.png
# processing (1855)-th image... ./datasets/train/syn_labels/11667.png
# processing (1860)-th image... ./datasets/train/syn_labels/11671.png
# processing (1865)-th image... ./datasets/train/syn_labels/11676.png
# processing (1870)-th image... ./datasets/train/syn_labels/11680.png
# processing (1875)-th image... ./datasets/train/syn_labels/11685.png
# processing (1880)-th image... ./datasets/train/syn_labels/1169.png
# processing (1885)-th image... ./datasets/train/syn_labels/11694.png
# processing (1890)-th image... ./datasets/train/syn_labels/11699.png
# processing (1895)-th image... ./datasets/train/syn_labels/11702.png
# processing (1900)-th image... ./datasets/train/syn_labels/11707.png
# processing (1905)-th image... ./datasets/train/syn_labels/11711.png
# processing (1910)-th image... ./datasets/train/syn_labels/11716.png
# processing (1915)-th image... ./datasets/train/syn_labels/11720.png
# processing (1920)-th image... ./datasets/train/syn_labels/11725.png
# processing (1925)-th image... ./datasets/train/syn_labels/1173.png
# processing (1930)-th image... ./datasets/train/syn_labels/11734.png
# processing (1935)-th image... ./datasets/train/syn_labels/11739.png
# processing (1940)-th image... ./datasets/train/syn_labels/11743.png
# processing (1945)-th image... ./datasets/train/syn_labels/11748.png
# processing (1950)-th image... ./datasets/train/syn_labels/11752.png
# processing (1955)-th image... ./datasets/train/syn_labels/11757.png
# processing (1960)-th image... ./datasets/train/syn_labels/11761.png
# processing (1965)-th image... ./datasets/train/syn_labels/11766.png
# processing (1970)-th image... ./datasets/train/syn_labels/11770.png
# processing (1975)-th image... ./datasets/train/syn_labels/11775.png
# processing (1980)-th image... ./datasets/train/syn_labels/1178.png
# processing (1985)-th image... ./datasets/train/syn_labels/11784.png
# processing (1990)-th image... ./datasets/train/syn_labels/11789.png
# processing (1995)-th image... ./datasets/train/syn_labels/11793.png
# processing (2000)-th image... ./datasets/train/syn_labels/11798.png
# processing (2005)-th image... ./datasets/train/syn_labels/11801.png
# processing (2010)-th image... ./datasets/train/syn_labels/11806.png
# processing (2015)-th image... ./datasets/train/syn_labels/11810.png
# processing (2020)-th image... ./datasets/train/syn_labels/11815.png
# processing (2025)-th image... ./datasets/train/syn_labels/1182.png
# processing (2030)-th image... ./datasets/train/syn_labels/11824.png
# processing (2035)-th image... ./datasets/train/syn_labels/11829.png
# processing (2040)-th image... ./datasets/train/syn_labels/11833.png
# processing (2045)-th image... ./datasets/train/syn_labels/11838.png
# processing (2050)-th image... ./datasets/train/syn_labels/11842.png
# processing (2055)-th image... ./datasets/train/syn_labels/11847.png
# processing (2060)-th image... ./datasets/train/syn_labels/11851.png
# processing (2065)-th image... ./datasets/train/syn_labels/11856.png
# processing (2070)-th image... ./datasets/train/syn_labels/11860.png
# processing (2075)-th image... ./datasets/train/syn_labels/11865.png
# processing (2080)-th image... ./datasets/train/syn_labels/1187.png
# processing (2085)-th image... ./datasets/train/syn_labels/11874.png
# processing (2090)-th image... ./datasets/train/syn_labels/11879.png
# processing (2095)-th image... ./datasets/train/syn_labels/11883.png
# processing (2100)-th image... ./datasets/train/syn_labels/11888.png
# processing (2105)-th image... ./datasets/train/syn_labels/11892.png
# processing (2110)-th image... ./datasets/train/syn_labels/11897.png
# processing (2115)-th image... ./datasets/train/syn_labels/11900.png
# processing (2120)-th image... ./datasets/train/syn_labels/11905.png
# processing (2125)-th image... ./datasets/train/syn_labels/1191.png
# processing (2130)-th image... ./datasets/train/syn_labels/11914.png
# processing (2135)-th image... ./datasets/train/syn_labels/11919.png
# processing (2140)-th image... ./datasets/train/syn_labels/11923.png
# processing (2145)-th image... ./datasets/train/syn_labels/11928.png
# processing (2150)-th image... ./datasets/train/syn_labels/11932.png
# processing (2155)-th image... ./datasets/train/syn_labels/11937.png
# processing (2160)-th image... ./datasets/train/syn_labels/11941.png
# processing (2165)-th image... ./datasets/train/syn_labels/11946.png
# processing (2170)-th image... ./datasets/train/syn_labels/11950.png
# processing (2175)-th image... ./datasets/train/syn_labels/11955.png
# processing (2180)-th image... ./datasets/train/syn_labels/1196.png
# processing (2185)-th image... ./datasets/train/syn_labels/11964.png
# processing (2190)-th image... ./datasets/train/syn_labels/11969.png
# processing (2195)-th image... ./datasets/train/syn_labels/11973.png
# processing (2200)-th image... ./datasets/train/syn_labels/11978.png
# processing (2205)-th image... ./datasets/train/syn_labels/11982.png
# processing (2210)-th image... ./datasets/train/syn_labels/11987.png
# processing (2215)-th image... ./datasets/train/syn_labels/11991.png
# processing (2220)-th image... ./datasets/train/syn_labels/11996.png
# processing (2225)-th image... ./datasets/train/syn_labels/120.png
# processing (2230)-th image... ./datasets/train/syn_labels/12003.png
# processing (2235)-th image... ./datasets/train/syn_labels/12008.png
# processing (2240)-th image... ./datasets/train/syn_labels/12012.png
# processing (2245)-th image... ./datasets/train/syn_labels/12017.png
# processing (2250)-th image... ./datasets/train/syn_labels/12021.png
# processing (2255)-th image... ./datasets/train/syn_labels/12026.png
# processing (2260)-th image... ./datasets/train/syn_labels/12030.png
# processing (2265)-th image... ./datasets/train/syn_labels/12035.png
# processing (2270)-th image... ./datasets/train/syn_labels/1204.png
# processing (2275)-th image... ./datasets/train/syn_labels/12044.png
# processing (2280)-th image... ./datasets/train/syn_labels/12049.png
# processing (2285)-th image... ./datasets/train/syn_labels/12053.png
# processing (2290)-th image... ./datasets/train/syn_labels/12058.png
# processing (2295)-th image... ./datasets/train/syn_labels/12062.png
# processing (2300)-th image... ./datasets/train/syn_labels/12067.png
# processing (2305)-th image... ./datasets/train/syn_labels/12071.png
# processing (2310)-th image... ./datasets/train/syn_labels/12076.png
# processing (2315)-th image... ./datasets/train/syn_labels/12080.png
# processing (2320)-th image... ./datasets/train/syn_labels/12085.png
# processing (2325)-th image... ./datasets/train/syn_labels/1209.png
# processing (2330)-th image... ./datasets/train/syn_labels/12094.png
# processing (2335)-th image... ./datasets/train/syn_labels/12099.png
# processing (2340)-th image... ./datasets/train/syn_labels/12102.png
# processing (2345)-th image... ./datasets/train/syn_labels/12107.png
# processing (2350)-th image... ./datasets/train/syn_labels/12111.png
# processing (2355)-th image... ./datasets/train/syn_labels/12116.png
# processing (2360)-th image... ./datasets/train/syn_labels/12120.png
# processing (2365)-th image... ./datasets/train/syn_labels/12125.png
# processing (2370)-th image... ./datasets/train/syn_labels/1213.png
# processing (2375)-th image... ./datasets/train/syn_labels/12134.png
# processing (2380)-th image... ./datasets/train/syn_labels/12139.png
# processing (2385)-th image... ./datasets/train/syn_labels/12143.png
# processing (2390)-th image... ./datasets/train/syn_labels/12148.png
# processing (2395)-th image... ./datasets/train/syn_labels/12152.png
# processing (2400)-th image... ./datasets/train/syn_labels/12157.png
# processing (2405)-th image... ./datasets/train/syn_labels/12161.png
# processing (2410)-th image... ./datasets/train/syn_labels/12166.png
# processing (2415)-th image... ./datasets/train/syn_labels/12170.png
# processing (2420)-th image... ./datasets/train/syn_labels/12175.png
# processing (2425)-th image... ./datasets/train/syn_labels/1218.png
# processing (2430)-th image... ./datasets/train/syn_labels/12184.png
# processing (2435)-th image... ./datasets/train/syn_labels/12189.png
# processing (2440)-th image... ./datasets/train/syn_labels/12193.png
# processing (2445)-th image... ./datasets/train/syn_labels/12198.png
# processing (2450)-th image... ./datasets/train/syn_labels/12201.png
# processing (2455)-th image... ./datasets/train/syn_labels/12206.png
# processing (2460)-th image... ./datasets/train/syn_labels/12210.png
# processing (2465)-th image... ./datasets/train/syn_labels/12215.png
# processing (2470)-th image... ./datasets/train/syn_labels/1222.png
# processing (2475)-th image... ./datasets/train/syn_labels/12224.png
# processing (2480)-th image... ./datasets/train/syn_labels/12229.png
# processing (2485)-th image... ./datasets/train/syn_labels/12233.png
# processing (2490)-th image... ./datasets/train/syn_labels/12238.png
# processing (2495)-th image... ./datasets/train/syn_labels/12242.png
# processing (2500)-th image... ./datasets/train/syn_labels/12247.png
# processing (2505)-th image... ./datasets/train/syn_labels/12251.png
# processing (2510)-th image... ./datasets/train/syn_labels/12256.png
# processing (2515)-th image... ./datasets/train/syn_labels/12260.png
# processing (2520)-th image... ./datasets/train/syn_labels/12265.png
# processing (2525)-th image... ./datasets/train/syn_labels/1227.png
# processing (2530)-th image... ./datasets/train/syn_labels/12274.png
# processing (2535)-th image... ./datasets/train/syn_labels/12279.png
# processing (2540)-th image... ./datasets/train/syn_labels/12283.png
# processing (2545)-th image... ./datasets/train/syn_labels/12288.png
# processing (2550)-th image... ./datasets/train/syn_labels/12292.png
# processing (2555)-th image... ./datasets/train/syn_labels/12297.png
# processing (2560)-th image... ./datasets/train/syn_labels/12300.png
# processing (2565)-th image... ./datasets/train/syn_labels/12305.png
# processing (2570)-th image... ./datasets/train/syn_labels/1231.png
# processing (2575)-th image... ./datasets/train/syn_labels/12314.png
# processing (2580)-th image... ./datasets/train/syn_labels/12319.png
# processing (2585)-th image... ./datasets/train/syn_labels/12323.png
# processing (2590)-th image... ./datasets/train/syn_labels/12328.png
# processing (2595)-th image... ./datasets/train/syn_labels/12332.png
# processing (2600)-th image... ./datasets/train/syn_labels/12337.png
# processing (2605)-th image... ./datasets/train/syn_labels/12341.png
# processing (2610)-th image... ./datasets/train/syn_labels/12346.png
# processing (2615)-th image... ./datasets/train/syn_labels/12350.png
# processing (2620)-th image... ./datasets/train/syn_labels/12355.png
# processing (2625)-th image... ./datasets/train/syn_labels/1236.png
# processing (2630)-th image... ./datasets/train/syn_labels/12364.png
# processing (2635)-th image... ./datasets/train/syn_labels/12369.png
# processing (2640)-th image... ./datasets/train/syn_labels/12373.png
# processing (2645)-th image... ./datasets/train/syn_labels/12378.png
# processing (2650)-th image... ./datasets/train/syn_labels/12382.png
# processing (2655)-th image... ./datasets/train/syn_labels/12387.png
# processing (2660)-th image... ./datasets/train/syn_labels/12391.png
# processing (2665)-th image... ./datasets/train/syn_labels/12396.png
# processing (2670)-th image... ./datasets/train/syn_labels/1240.png
# processing (2675)-th image... ./datasets/train/syn_labels/12404.png
# processing (2680)-th image... ./datasets/train/syn_labels/12409.png
# processing (2685)-th image... ./datasets/train/syn_labels/12413.png
# processing (2690)-th image... ./datasets/train/syn_labels/12418.png
# processing (2695)-th image... ./datasets/train/syn_labels/12422.png
# processing (2700)-th image... ./datasets/train/syn_labels/12427.png
# processing (2705)-th image... ./datasets/train/syn_labels/12431.png
# processing (2710)-th image... ./datasets/train/syn_labels/12436.png
# processing (2715)-th image... ./datasets/train/syn_labels/12440.png
# processing (2720)-th image... ./datasets/train/syn_labels/12445.png
# processing (2725)-th image... ./datasets/train/syn_labels/1245.png
# processing (2730)-th image... ./datasets/train/syn_labels/12454.png
# processing (2735)-th image... ./datasets/train/syn_labels/12459.png
# processing (2740)-th image... ./datasets/train/syn_labels/12463.png
# processing (2745)-th image... ./datasets/train/syn_labels/12468.png
# processing (2750)-th image... ./datasets/train/syn_labels/12472.png
# processing (2755)-th image... ./datasets/train/syn_labels/12477.png
# processing (2760)-th image... ./datasets/train/syn_labels/12481.png
# processing (2765)-th image... ./datasets/train/syn_labels/12486.png
# processing (2770)-th image... ./datasets/train/syn_labels/12490.png
# processing (2775)-th image... ./datasets/train/syn_labels/12495.png
# processing (2780)-th image... ./datasets/train/syn_labels/125.png
# processing (2785)-th image... ./datasets/train/syn_labels/12503.png
# processing (2790)-th image... ./datasets/train/syn_labels/12508.png
# processing (2795)-th image... ./datasets/train/syn_labels/12512.png
# processing (2800)-th image... ./datasets/train/syn_labels/12517.png
# processing (2805)-th image... ./datasets/train/syn_labels/12521.png
# processing (2810)-th image... ./datasets/train/syn_labels/12526.png
# processing (2815)-th image... ./datasets/train/syn_labels/12530.png
# processing (2820)-th image... ./datasets/train/syn_labels/12535.png
# processing (2825)-th image... ./datasets/train/syn_labels/1254.png
# processing (2830)-th image... ./datasets/train/syn_labels/12544.png
# processing (2835)-th image... ./datasets/train/syn_labels/12549.png
# processing (2840)-th image... ./datasets/train/syn_labels/12553.png
# processing (2845)-th image... ./datasets/train/syn_labels/12558.png
# processing (2850)-th image... ./datasets/train/syn_labels/12562.png
# processing (2855)-th image... ./datasets/train/syn_labels/12567.png
# processing (2860)-th image... ./datasets/train/syn_labels/12571.png
# processing (2865)-th image... ./datasets/train/syn_labels/12576.png
# processing (2870)-th image... ./datasets/train/syn_labels/12580.png
# processing (2875)-th image... ./datasets/train/syn_labels/12585.png
# processing (2880)-th image... ./datasets/train/syn_labels/1259.png
# processing (2885)-th image... ./datasets/train/syn_labels/12594.png
# processing (2890)-th image... ./datasets/train/syn_labels/12599.png
# processing (2895)-th image... ./datasets/train/syn_labels/12602.png
# processing (2900)-th image... ./datasets/train/syn_labels/12607.png
# processing (2905)-th image... ./datasets/train/syn_labels/12611.png
# processing (2910)-th image... ./datasets/train/syn_labels/12616.png
# processing (2915)-th image... ./datasets/train/syn_labels/12620.png
# processing (2920)-th image... ./datasets/train/syn_labels/12625.png
# processing (2925)-th image... ./datasets/train/syn_labels/1263.png
# processing (2930)-th image... ./datasets/train/syn_labels/12634.png
# processing (2935)-th image... ./datasets/train/syn_labels/12639.png
# processing (2940)-th image... ./datasets/train/syn_labels/12643.png
# processing (2945)-th image... ./datasets/train/syn_labels/12648.png
# processing (2950)-th image... ./datasets/train/syn_labels/12652.png
# processing (2955)-th image... ./datasets/train/syn_labels/12657.png
# processing (2960)-th image... ./datasets/train/syn_labels/12661.png
# processing (2965)-th image... ./datasets/train/syn_labels/12666.png
# processing (2970)-th image... ./datasets/train/syn_labels/12670.png
# processing (2975)-th image... ./datasets/train/syn_labels/12675.png
# processing (2980)-th image... ./datasets/train/syn_labels/1268.png
# processing (2985)-th image... ./datasets/train/syn_labels/12684.png
# processing (2990)-th image... ./datasets/train/syn_labels/12689.png
# processing (2995)-th image... ./datasets/train/syn_labels/12693.png
# processing (3000)-th image... ./datasets/train/syn_labels/12698.png
# processing (3005)-th image... ./datasets/train/syn_labels/12701.png
# processing (3010)-th image... ./datasets/train/syn_labels/12706.png
# processing (3015)-th image... ./datasets/train/syn_labels/12710.png
# processing (3020)-th image... ./datasets/train/syn_labels/12715.png
# processing (3025)-th image... ./datasets/train/syn_labels/1272.png
# processing (3030)-th image... ./datasets/train/syn_labels/12724.png
# processing (3035)-th image... ./datasets/train/syn_labels/12729.png
# processing (3040)-th image... ./datasets/train/syn_labels/12733.png
# processing (3045)-th image... ./datasets/train/syn_labels/12738.png
# processing (3050)-th image... ./datasets/train/syn_labels/12742.png
# processing (3055)-th image... ./datasets/train/syn_labels/12747.png
# processing (3060)-th image... ./datasets/train/syn_labels/12751.png
# processing (3065)-th image... ./datasets/train/syn_labels/12756.png
# processing (3070)-th image... ./datasets/train/syn_labels/12760.png
# processing (3075)-th image... ./datasets/train/syn_labels/12765.png
# processing (3080)-th image... ./datasets/train/syn_labels/1277.png
# processing (3085)-th image... ./datasets/train/syn_labels/12774.png
# processing (3090)-th image... ./datasets/train/syn_labels/12779.png
# processing (3095)-th image... ./datasets/train/syn_labels/12783.png
# processing (3100)-th image... ./datasets/train/syn_labels/12788.png
# processing (3105)-th image... ./datasets/train/syn_labels/12792.png
# processing (3110)-th image... ./datasets/train/syn_labels/12797.png
# processing (3115)-th image... ./datasets/train/syn_labels/12800.png
# processing (3120)-th image... ./datasets/train/syn_labels/12805.png
# processing (3125)-th image... ./datasets/train/syn_labels/1281.png
# processing (3130)-th image... ./datasets/train/syn_labels/12814.png
# processing (3135)-th image... ./datasets/train/syn_labels/12819.png
# processing (3140)-th image... ./datasets/train/syn_labels/12823.png
# processing (3145)-th image... ./datasets/train/syn_labels/12828.png
# processing (3150)-th image... ./datasets/train/syn_labels/12832.png
# processing (3155)-th image... ./datasets/train/syn_labels/12837.png
# processing (3160)-th image... ./datasets/train/syn_labels/12841.png
# processing (3165)-th image... ./datasets/train/syn_labels/12846.png
# processing (3170)-th image... ./datasets/train/syn_labels/12850.png
# processing (3175)-th image... ./datasets/train/syn_labels/12855.png
# processing (3180)-th image... ./datasets/train/syn_labels/1286.png
# processing (3185)-th image... ./datasets/train/syn_labels/12864.png
# processing (3190)-th image... ./datasets/train/syn_labels/12869.png
# processing (3195)-th image... ./datasets/train/syn_labels/12873.png
# processing (3200)-th image... ./datasets/train/syn_labels/12878.png
# processing (3205)-th image... ./datasets/train/syn_labels/12882.png
# processing (3210)-th image... ./datasets/train/syn_labels/12887.png
# processing (3215)-th image... ./datasets/train/syn_labels/12891.png
# processing (3220)-th image... ./datasets/train/syn_labels/12896.png
# processing (3225)-th image... ./datasets/train/syn_labels/1290.png
# processing (3230)-th image... ./datasets/train/syn_labels/12904.png
# processing (3235)-th image... ./datasets/train/syn_labels/12909.png
# processing (3240)-th image... ./datasets/train/syn_labels/12913.png
# processing (3245)-th image... ./datasets/train/syn_labels/12918.png
# processing (3250)-th image... ./datasets/train/syn_labels/12922.png
# processing (3255)-th image... ./datasets/train/syn_labels/12927.png
# processing (3260)-th image... ./datasets/train/syn_labels/12931.png
# processing (3265)-th image... ./datasets/train/syn_labels/12936.png
# processing (3270)-th image... ./datasets/train/syn_labels/12940.png
# processing (3275)-th image... ./datasets/train/syn_labels/12945.png
# processing (3280)-th image... ./datasets/train/syn_labels/1295.png
# processing (3285)-th image... ./datasets/train/syn_labels/12954.png
# processing (3290)-th image... ./datasets/train/syn_labels/12959.png
# processing (3295)-th image... ./datasets/train/syn_labels/12963.png
# processing (3300)-th image... ./datasets/train/syn_labels/12968.png
# processing (3305)-th image... ./datasets/train/syn_labels/12972.png
# processing (3310)-th image... ./datasets/train/syn_labels/12977.png
# processing (3315)-th image... ./datasets/train/syn_labels/12981.png
# processing (3320)-th image... ./datasets/train/syn_labels/12986.png
# processing (3325)-th image... ./datasets/train/syn_labels/12990.png
# ...
# processing (27625)-th image... ./datasets/train/syn_labels/8941.png
# processing (27630)-th image... ./datasets/train/syn_labels/8946.png
# processing (27635)-th image... ./datasets/train/syn_labels/8950.png
# processing (27640)-th image... ./datasets/train/syn_labels/8955.png
# processing (27645)-th image... ./datasets/train/syn_labels/896.png
# processing (27650)-th image... ./datasets/train/syn_labels/8964.png
# processing (27655)-th image... ./datasets/train/syn_labels/8969.png
# processing (27660)-th image... ./datasets/train/syn_labels/8973.png
# processing (27665)-th image... ./datasets/train/syn_labels/8978.png
# processing (27670)-th image... ./datasets/train/syn_labels/8982.png
# processing (27675)-th image... ./datasets/train/syn_labels/8987.png
# processing (27680)-th image... ./datasets/train/syn_labels/8991.png
# processing (27685)-th image... ./datasets/train/syn_labels/8996.png
# processing (27690)-th image... ./datasets/train/syn_labels/90.png
# processing (27695)-th image... ./datasets/train/syn_labels/9003.png
# processing (27700)-th image... ./datasets/train/syn_labels/9008.png
# processing (27705)-th image... ./datasets/train/syn_labels/9012.png
# processing (27710)-th image... ./datasets/train/syn_labels/9017.png
# processing (27715)-th image... ./datasets/train/syn_labels/9021.png
# processing (27720)-th image... ./datasets/train/syn_labels/9026.png
# processing (27725)-th image... ./datasets/train/syn_labels/9030.png
# processing (27730)-th image... ./datasets/train/syn_labels/9035.png
# processing (27735)-th image... ./datasets/train/syn_labels/904.png
# processing (27740)-th image... ./datasets/train/syn_labels/9044.png
# processing (27745)-th image... ./datasets/train/syn_labels/9049.png
# processing (27750)-th image... ./datasets/train/syn_labels/9053.png
# processing (27755)-th image... ./datasets/train/syn_labels/9058.png
# processing (27760)-th image... ./datasets/train/syn_labels/9062.png
# processing (27765)-th image... ./datasets/train/syn_labels/9067.png
# processing (27770)-th image... ./datasets/train/syn_labels/9071.png
# processing (27775)-th image... ./datasets/train/syn_labels/9076.png
# processing (27780)-th image... ./datasets/train/syn_labels/9080.png
# processing (27785)-th image... ./datasets/train/syn_labels/9085.png
# processing (27790)-th image... ./datasets/train/syn_labels/909.png
# processing (27795)-th image... ./datasets/train/syn_labels/9094.png
# processing (27800)-th image... ./datasets/train/syn_labels/9099.png
# processing (27805)-th image... ./datasets/train/syn_labels/9102.png
# processing (27810)-th image... ./datasets/train/syn_labels/9107.png
# processing (27815)-th image... ./datasets/train/syn_labels/9111.png
# processing (27820)-th image... ./datasets/train/syn_labels/9116.png
# processing (27825)-th image... ./datasets/train/syn_labels/9120.png
# processing (27830)-th image... ./datasets/train/syn_labels/9125.png
# processing (27835)-th image... ./datasets/train/syn_labels/913.png
# processing (27840)-th image... ./datasets/train/syn_labels/9134.png
# processing (27845)-th image... ./datasets/train/syn_labels/9139.png
# processing (27850)-th image... ./datasets/train/syn_labels/9143.png
# processing (27855)-th image... ./datasets/train/syn_labels/9148.png
# processing (27860)-th image... ./datasets/train/syn_labels/9152.png
# processing (27865)-th image... ./datasets/train/syn_labels/9157.png
# processing (27870)-th image... ./datasets/train/syn_labels/9161.png
# processing (27875)-th image... ./datasets/train/syn_labels/9166.png
# processing (27880)-th image... ./datasets/train/syn_labels/9170.png
# processing (27885)-th image... ./datasets/train/syn_labels/9175.png
# processing (27890)-th image... ./datasets/train/syn_labels/918.png
# processing (27895)-th image... ./datasets/train/syn_labels/9184.png
# processing (27900)-th image... ./datasets/train/syn_labels/9189.png
# processing (27905)-th image... ./datasets/train/syn_labels/9193.png
# processing (27910)-th image... ./datasets/train/syn_labels/9198.png
# processing (27915)-th image... ./datasets/train/syn_labels/9201.png
# processing (27920)-th image... ./datasets/train/syn_labels/9206.png
# processing (27925)-th image... ./datasets/train/syn_labels/9210.png
# processing (27930)-th image... ./datasets/train/syn_labels/9215.png
# processing (27935)-th image... ./datasets/train/syn_labels/922.png
# processing (27940)-th image... ./datasets/train/syn_labels/9224.png
# processing (27945)-th image... ./datasets/train/syn_labels/9229.png
# processing (27950)-th image... ./datasets/train/syn_labels/9233.png
# processing (27955)-th image... ./datasets/train/syn_labels/9238.png
# processing (27960)-th image... ./datasets/train/syn_labels/9242.png
# processing (27965)-th image... ./datasets/train/syn_labels/9247.png
# processing (27970)-th image... ./datasets/train/syn_labels/9251.png
# processing (27975)-th image... ./datasets/train/syn_labels/9256.png
# processing (27980)-th image... ./datasets/train/syn_labels/9260.png
# processing (27985)-th image... ./datasets/train/syn_labels/9265.png
# processing (27990)-th image... ./datasets/train/syn_labels/927.png
# processing (27995)-th image... ./datasets/train/syn_labels/9274.png
# processing (28000)-th image... ./datasets/train/syn_labels/9279.png
# processing (28005)-th image... ./datasets/train/syn_labels/9283.png
# processing (28010)-th image... ./datasets/train/syn_labels/9288.png
# processing (28015)-th image... ./datasets/train/syn_labels/9292.png
# processing (28020)-th image... ./datasets/train/syn_labels/9297.png
# processing (28025)-th image... ./datasets/train/syn_labels/9300.png
# processing (28030)-th image... ./datasets/train/syn_labels/9305.png
# processing (28035)-th image... ./datasets/train/syn_labels/931.png
# processing (28040)-th image... ./datasets/train/syn_labels/9314.png
# processing (28045)-th image... ./datasets/train/syn_labels/9319.png
# processing (28050)-th image... ./datasets/train/syn_labels/9323.png
# processing (28055)-th image... ./datasets/train/syn_labels/9328.png
# processing (28060)-th image... ./datasets/train/syn_labels/9332.png
# processing (28065)-th image... ./datasets/train/syn_labels/9337.png
# processing (28070)-th image... ./datasets/train/syn_labels/9341.png
# processing (28075)-th image... ./datasets/train/syn_labels/9346.png
# processing (28080)-th image... ./datasets/train/syn_labels/9350.png
# processing (28085)-th image... ./datasets/train/syn_labels/9355.png
# processing (28090)-th image... ./datasets/train/syn_labels/936.png
# processing (28095)-th image... ./datasets/train/syn_labels/9364.png
# processing (28100)-th image... ./datasets/train/syn_labels/9369.png
# processing (28105)-th image... ./datasets/train/syn_labels/9373.png
# processing (28110)-th image... ./datasets/train/syn_labels/9378.png
# processing (28115)-th image... ./datasets/train/syn_labels/9382.png
# processing (28120)-th image... ./datasets/train/syn_labels/9387.png
# processing (28125)-th image... ./datasets/train/syn_labels/9391.png
# processing (28130)-th image... ./datasets/train/syn_labels/9396.png
# processing (28135)-th image... ./datasets/train/syn_labels/940.png
# processing (28140)-th image... ./datasets/train/syn_labels/9404.png
# processing (28145)-th image... ./datasets/train/syn_labels/9409.png
# processing (28150)-th image... ./datasets/train/syn_labels/9413.png
# processing (28155)-th image... ./datasets/train/syn_labels/9418.png
# processing (28160)-th image... ./datasets/train/syn_labels/9422.png
# processing (28165)-th image... ./datasets/train/syn_labels/9427.png
# processing (28170)-th image... ./datasets/train/syn_labels/9431.png
# processing (28175)-th image... ./datasets/train/syn_labels/9436.png
# processing (28180)-th image... ./datasets/train/syn_labels/9440.png
# processing (28185)-th image... ./datasets/train/syn_labels/9445.png
# processing (28190)-th image... ./datasets/train/syn_labels/945.png
# processing (28195)-th image... ./datasets/train/syn_labels/9454.png
# processing (28200)-th image... ./datasets/train/syn_labels/9459.png
# processing (28205)-th image... ./datasets/train/syn_labels/9463.png
# processing (28210)-th image... ./datasets/train/syn_labels/9468.png
# processing (28215)-th image... ./datasets/train/syn_labels/9472.png
# processing (28220)-th image... ./datasets/train/syn_labels/9477.png
# processing (28225)-th image... ./datasets/train/syn_labels/9481.png
# processing (28230)-th image... ./datasets/train/syn_labels/9486.png
# processing (28235)-th image... ./datasets/train/syn_labels/9490.png
# processing (28240)-th image... ./datasets/train/syn_labels/9495.png
# processing (28245)-th image... ./datasets/train/syn_labels/95.png
# processing (28250)-th image... ./datasets/train/syn_labels/9503.png
# processing (28255)-th image... ./datasets/train/syn_labels/9508.png
# processing (28260)-th image... ./datasets/train/syn_labels/9512.png
# processing (28265)-th image... ./datasets/train/syn_labels/9517.png
# processing (28270)-th image... ./datasets/train/syn_labels/9521.png
# processing (28275)-th image... ./datasets/train/syn_labels/9526.png
# processing (28280)-th image... ./datasets/train/syn_labels/9530.png
# processing (28285)-th image... ./datasets/train/syn_labels/9535.png
# processing (28290)-th image... ./datasets/train/syn_labels/954.png
# processing (28295)-th image... ./datasets/train/syn_labels/9544.png
# processing (28300)-th image... ./datasets/train/syn_labels/9549.png
# processing (28305)-th image... ./datasets/train/syn_labels/9553.png
# processing (28310)-th image... ./datasets/train/syn_labels/9558.png
# processing (28315)-th image... ./datasets/train/syn_labels/9562.png
# processing (28320)-th image... ./datasets/train/syn_labels/9567.png
# processing (28325)-th image... ./datasets/train/syn_labels/9571.png
# processing (28330)-th image... ./datasets/train/syn_labels/9576.png
# processing (28335)-th image... ./datasets/train/syn_labels/9580.png
# processing (28340)-th image... ./datasets/train/syn_labels/9585.png
# processing (28345)-th image... ./datasets/train/syn_labels/959.png
# processing (28350)-th image... ./datasets/train/syn_labels/9594.png
# processing (28355)-th image... ./datasets/train/syn_labels/9599.png
# processing (28360)-th image... ./datasets/train/syn_labels/9602.png
# processing (28365)-th image... ./datasets/train/syn_labels/9607.png
# processing (28370)-th image... ./datasets/train/syn_labels/9611.png
# processing (28375)-th image... ./datasets/train/syn_labels/9616.png
# processing (28380)-th image... ./datasets/train/syn_labels/9620.png
# processing (28385)-th image... ./datasets/train/syn_labels/9625.png
# processing (28390)-th image... ./datasets/train/syn_labels/963.png
# processing (28395)-th image... ./datasets/train/syn_labels/9634.png
# processing (28400)-th image... ./datasets/train/syn_labels/9639.png
# processing (28405)-th image... ./datasets/train/syn_labels/9643.png
# processing (28410)-th image... ./datasets/train/syn_labels/9648.png
# processing (28415)-th image... ./datasets/train/syn_labels/9652.png
# processing (28420)-th image... ./datasets/train/syn_labels/9657.png
# processing (28425)-th image... ./datasets/train/syn_labels/9661.png
# processing (28430)-th image... ./datasets/train/syn_labels/9666.png
# processing (28435)-th image... ./datasets/train/syn_labels/9670.png
# processing (28440)-th image... ./datasets/train/syn_labels/9675.png
# processing (28445)-th image... ./datasets/train/syn_labels/968.png
# processing (28450)-th image... ./datasets/train/syn_labels/9684.png
# processing (28455)-th image... ./datasets/train/syn_labels/9689.png
# processing (28460)-th image... ./datasets/train/syn_labels/9693.png
# processing (28465)-th image... ./datasets/train/syn_labels/9698.png
# processing (28470)-th image... ./datasets/train/syn_labels/9701.png
# processing (28475)-th image... ./datasets/train/syn_labels/9706.png
# processing (28480)-th image... ./datasets/train/syn_labels/9710.png
# processing (28485)-th image... ./datasets/train/syn_labels/9715.png
# processing (28490)-th image... ./datasets/train/syn_labels/972.png
# processing (28495)-th image... ./datasets/train/syn_labels/9724.png
# processing (28500)-th image... ./datasets/train/syn_labels/9729.png
# processing (28505)-th image... ./datasets/train/syn_labels/9733.png
# processing (28510)-th image... ./datasets/train/syn_labels/9738.png
# processing (28515)-th image... ./datasets/train/syn_labels/9742.png
# processing (28520)-th image... ./datasets/train/syn_labels/9747.png
# processing (28525)-th image... ./datasets/train/syn_labels/9751.png
# processing (28530)-th image... ./datasets/train/syn_labels/9756.png
# processing (28535)-th image... ./datasets/train/syn_labels/9760.png
# processing (28540)-th image... ./datasets/train/syn_labels/9765.png
# processing (28545)-th image... ./datasets/train/syn_labels/977.png
# processing (28550)-th image... ./datasets/train/syn_labels/9774.png
# processing (28555)-th image... ./datasets/train/syn_labels/9779.png
# processing (28560)-th image... ./datasets/train/syn_labels/9783.png
# processing (28565)-th image... ./datasets/train/syn_labels/9788.png
# processing (28570)-th image... ./datasets/train/syn_labels/9792.png
# processing (28575)-th image... ./datasets/train/syn_labels/9797.png
# processing (28580)-th image... ./datasets/train/syn_labels/9800.png
# processing (28585)-th image... ./datasets/train/syn_labels/9805.png
# processing (28590)-th image... ./datasets/train/syn_labels/981.png
# processing (28595)-th image... ./datasets/train/syn_labels/9814.png
# processing (28600)-th image... ./datasets/train/syn_labels/9819.png
# processing (28605)-th image... ./datasets/train/syn_labels/9823.png
# processing (28610)-th image... ./datasets/train/syn_labels/9828.png
# processing (28615)-th image... ./datasets/train/syn_labels/9832.png
# processing (28620)-th image... ./datasets/train/syn_labels/9837.png
# processing (28625)-th image... ./datasets/train/syn_labels/9841.png
# processing (28630)-th image... ./datasets/train/syn_labels/9846.png
# processing (28635)-th image... ./datasets/train/syn_labels/9850.png
# processing (28640)-th image... ./datasets/train/syn_labels/9855.png
# processing (28645)-th image... ./datasets/train/syn_labels/986.png
# processing (28650)-th image... ./datasets/train/syn_labels/9864.png
# processing (28655)-th image... ./datasets/train/syn_labels/9869.png
# processing (28660)-th image... ./datasets/train/syn_labels/9873.png
# processing (28665)-th image... ./datasets/train/syn_labels/9878.png
# processing (28670)-th image... ./datasets/train/syn_labels/9882.png
# processing (28675)-th image... ./datasets/train/syn_labels/9887.png
# processing (28680)-th image... ./datasets/train/syn_labels/9891.png
# processing (28685)-th image... ./datasets/train/syn_labels/9896.png
# processing (28690)-th image... ./datasets/train/syn_labels/990.png
# processing (28695)-th image... ./datasets/train/syn_labels/9904.png
# processing (28700)-th image... ./datasets/train/syn_labels/9909.png
# processing (28705)-th image... ./datasets/train/syn_labels/9913.png
# processing (28710)-th image... ./datasets/train/syn_labels/9918.png
# processing (28715)-th image... ./datasets/train/syn_labels/9922.png
# processing (28720)-th image... ./datasets/train/syn_labels/9927.png
# processing (28725)-th image... ./datasets/train/syn_labels/9931.png
# processing (28730)-th image... ./datasets/train/syn_labels/9936.png
# processing (28735)-th image... ./datasets/train/syn_labels/9940.png
# processing (28740)-th image... ./datasets/train/syn_labels/9945.png
# processing (28745)-th image... ./datasets/train/syn_labels/995.png
# processing (28750)-th image... ./datasets/train/syn_labels/9954.png
# processing (28755)-th image... ./datasets/train/syn_labels/9959.png
# processing (28760)-th image... ./datasets/train/syn_labels/9963.png
# processing (28765)-th image... ./datasets/train/syn_labels/9968.png
# processing (28770)-th image... ./datasets/train/syn_labels/9972.png
# processing (28775)-th image... ./datasets/train/syn_labels/9977.png
# processing (28780)-th image... ./datasets/train/syn_labels/9981.png
# processing (28785)-th image... ./datasets/train/syn_labels/9986.png
# processing (28790)-th image... ./datasets/train/syn_labels/9990.png
# processing (28795)-th image... ./datasets/train/syn_labels/9995.png

# %%
#check dataset
# %matplotlib inline
# %run ./scripts/check_paired_dataset.py --check_num 10 \
--images_path './datasets/train/iron_label2real_pix2pix_real_5_o/latest/images/' \
--labels_path './datasets/train/iron_label2real_pix2pix_real_5_o/latest/labels/'
# Out:
# images num: 28800 |labels num : 28800
# get 4448.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 25386.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 13236.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 11763.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 22297.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 21970.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 28728.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 13118.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 6716.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]
# get 2694.png
# image size: 400 400 label size:400 400
# label classes:[  0 255]

# %%
#our method
#mix train unet
# %run ./scripts/train.py --net unet --train_type 'mix' --gpu_ids 2,3 \
--dataroot './datasets/' --batch_size 8 \
--train_img_dir_real 'train/real_images' \
--train_label_dir_real 'train/real_labels' \
--train_img_list_real './datasets/train/records_txt/real_5.txt' \
--train_img_dir_syn 'train/iron_label2real_pix2pix_real_5_o/latest/images' \
--train_label_dir_syn 'train/iron_label2real_pix2pix_real_5_o/latest/labels' \
--checkpoints_dir './ckpts/seg_models' \
--name 'model_real_5_mix_syn_o' \
--display_env 'model_real_5_mix_syn_o' \
--display_port 6006
# Out:
# ---------Options---------
#                batch_size: 8                             	[default: 1]
#           checkpoints_dir: ./ckpts/seg_models            	[default: ./model_checkpoints]
#            continue_train: False
#                  dataroot: ./datasets/                   	[default: ./datasets]
#              dataset_mode: aligned
#               display_env: model_real_5_mix_syn_o        	[default: main]
#                display_id: 1
#             display_ncols: 4
#              display_port: 6006                          	[default: 8097]
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: best_eval
#               epoch_count: 1
#                   gpu_ids: [2, 3]                        	[default: 0,1]
#                 init_gain: 1.0
#                 init_type: xavier_uniform
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 loss_type: CrossEntropyLoss
#               loss_weight: [1, 20]                       	[default: 1:20]
#                        lr: 0.0001
#            lr_decay_iters: 10
#                  lr_gamma: 0.8
#                 lr_policy: step
#          max_dataset_size: inf
#                     model: unet
#                      name: model_real_5_mix_syn_o        	[default: None]
#                       net: unet
#                   no_eval: False
#              no_normalize: False
#            no_postprocess: False
#               num_threads: 1
#                 output_nc: 2
#              save_by_iter: False
#           save_epoch_freq: 1
#          save_latest_freq: 2000
#      save_nums_each_epoch: 1
#            serial_batches: False
#                    suffix:
#              total_epochs: 100
#               total_iters: 35000
#        train_img_dir_real: train/real_images
#         train_img_dir_syn: train/iron_label2real_pix2pix_real_5_o/latest/images	[default: train/syn_images]
#       train_img_list_real: ./datasets/train/records_txt/real_5.txt	[default: ./datasets/train/real_35.txt]
#        train_img_list_syn: None
#      train_label_dir_real: train/real_labels
#       train_label_dir_syn: train/iron_label2real_pix2pix_real_5_o/latest/labels	[default: train/syn_labels]
#                train_type: mix
#            transform_mean: [0.94034111]                  	[default: 0.94034111]
#             transform_std: [0.12718913]                  	[default: 0.12718913]
#               val_img_dir: val/real_images
#              val_img_list: None
#             val_label_dir: val/real_labels
#                   verbose: False
# ----------------- End -------------------
# dataset [BaseDataset] was created
# #Synthetic training images = 28800, batchsize = 4
# dataset [BaseDataset] was created
# #Real training images = 140, batchsize = 4
# dataset [BaseDataset] was created
# #eval images = 100
# WARNING:root:Setting up a new session...
# initialize network with xavier_uniform
# model [UnetModel] was created
# ---------- Networks initialized -------------
# [Network ] Total number of parameters : 31.042 M
# -----------------------------------------------
# create images directory ./ckpts/seg_models/model_real_5_mix_syn_o/images...
# Training begin...total epochs:5
# saving the latest model (epoch 1, total_steps 2000)

# %%
#test our method
# %run ./scripts/test.py --net unet --name 'model_real_35_mix_syn_o'\
--checkpoints_dir './ckpts/seg_models/' \
--dataroot './datasets/test/' \
--test_img_dir 'real_images' \
--test_label_dir 'real_labels' \
--epoch 'epoch_5_7200' --results_dir './results/' --gpu_ids 0

# %%
#origin train unet
# %run ./scripts/train.py --net unet --train_type 'origin' --batch_size 8 --gpu_ids 0,1 \
--dataroot './datasets/' \
--train_img_dir_real 'train/real_images' \
--train_label_dir_real 'train/real_labels' \
--train_img_list_real './datasets/train/records_txt/real_35.txt' \
--val_img_dir 'val/real_images' \
--val_label_dir 'val/real_labels' \
--checkpoints_dir './ckpts/seg_models' \
--name 'model_real_35' \
--display_env 'model_real_35' \
--display_port 6006

# %%
#test origin unet
# %run ./scripts/test.py --net unet --name 'model_real_5'\
--checkpoints_dir './ckpts/seg_models/' \
--dataroot './datasets/test/' \
--test_img_dir 'real_images' \
--test_label_dir 'real_labels' \
--results_dir './results/' --gpu_ids 0

# %%
#ternausnet
#pretrained vgg11
# %run ./scripts/train.py --net unet11 --train_type 'origin' --batch_size 8 --gpu_ids 0,1 \
--dataroot './datasets/' \
--train_img_dir_real 'train/real_images' \
--train_label_dir_real 'train/real_labels' \
--train_img_list_real './datasets/train/records_txt/real_35.txt' \
--val_img_dir 'val/real_images' \
--val_label_dir 'val/real_labels' \
--checkpoints_dir './ckpts/seg_models' \
--name 'model_real_35_pretrained_vgg11' \
--display_env 'model_real_35_pretrained_vgg11' \
--display_port 6006

# %%
#test ternausnet with pretrained vgg11
# %run ./scripts/test.py --net unet11 --name 'model_real_35_pretrained_vgg11'\
--checkpoints_dir './ckpts/seg_models/' \
--dataroot './datasets/test/' \
--test_img_dir 'real_images' \
--test_label_dir 'real_labels' \
--epoch 'best_val' --results_dir './results/' --gpu_ids 0

# %%
#auto image segmentation by threshold, morphology seg and edge detection
#otsu|canny|watershed|kmeans...
# %run ./scripts/auto_segmentations.py --images_path './datasets/test/real_images/' --labels_path './datasets/test/real_labels/' \
--results_dir './results/others' --method 'kmeans'
